# %% [markdown]
# <a href="https://colab.research.google.com/github/poorna1995/Text-Summarisation/blob/main/Text_Summarisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
summariser = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
article = """
Currently pursuing a Master’s in Computer Science. Former Software Engineer with over 5 years of industrial experience.
Driven towards creating value for business technology stakeholders, bringing design and development innovation to the product. Experienced in diverse domains including E-Commerce, Consumer Technology, Finance, Networking, Construction Entertainment Industries. Proficient in building end-to-end development teams and project leadership.
Core Skills - Programming, DSA, Countinous Learner, Technical Acumen, Problem Solver, Decision Making EDUCATION
 University of Colorado Boulder
Master of Science in Computer Science.
Sri Venkateswara University, India
B.Tech. Major in Chemical Engineering
Overall CGPA: 7.3/10 (Distinction)
COURSE WORK Ongoing Course Work:
1. Advanced Data Structures, RSA and Quantum Algorithms 2. AWS Cloud Technology
Completed Course Work:
1. Dynamic Programming, Greedy Algorithms. Certificate: Link
2. Approximation Algorithms and Linear Programming. Certificate: Link 3. Algorithms for Searching, Sorting, and Indexing.
4. Trees and Graph.
2024 - present 2013 - 2017
 TECHNICAL SKILLS
Programming Languages • Web Technologies
Technical Skills Collaboration Tools
EXPERIENCE Aradit Technology
Senior Software Engineer
Worked building end-to-end diverse product portfolios in B2C & B2B domains
 Key Contributions to Live Products:
1. Llama (MVP Stage) 2. Lattis
3. Bluecom
4. Hivepath
5. Calpad
Engineering Leadership :
A all- in -one community platform
Platform for business and customer Interactions with AI Agents -Link E-commerce SaaS for streamlined product life cycle - Link Professional networking Platform - Link
A calendar booking platform for the professionals - Link
Python, R, Javascript
Django, PyTorch, TensorFlow, Typescript, ReactJS, NextJS, NodeJS, redux Data Structure, Algorithm, Pseudo Algorithm, Design Thinking, Design Strategy. GitHub Actions, Vercel, JIRA, Confluence, Trello, Slack, Zoom, Figma, Zeplin
 • Increased Speed-to-delivery process - Productivity, Collaboration & Communication.
• Technical Design leadership initiatives, researching and implementing state-of-the-art tools to enhance front-end
development efficiency and innovation.
• Standardized design patterns and component libraries across multiple platforms, promoting consistency, scalability, and efficient development cycles.
Sep 2021 - Present
Bangalore, India
Innovation in Development :

Developed versatile solutions for various industries, and customer segments use-cases (E-commerce, B2C Network- ing, SaaS products).
Built core engineering components for multi-customer channels (Android, iOS, Web, Desktop Apps) .
Enhanced AI-powered interfaces for personalized user interactions, enhancing overall usability and engagement. Implemented responsive design and progressive web app techniques.
Leadership Activities: Link

Engage in management reviews and board meetings to offer insights and recommendations for both strategy and engineering initiatives.
Introduce and integrate new technological innovations at Aradit, aligning them with product success. Delivered end-to-end fronted product life cycle (Creation, deliverance, Management and Maintenance)
Defined technical requirements, oversaw implementation, rigorously tested, and continuously improved front-end solutions.
Collaborated closely with cross-functional teams to align with UI/UX designs, user-centric principles, and overall product vision.
WhitePaper: Link Presentation: Link
nVipani Technology: Link Sep 2020 - Sep 2021
Software Engineer Bangalore, India
• Built user interfaces to provide the live shopping experience in virtual stores for both desktop and mobile customers.
• Conducted usability testing and gathered feedback from retailers and customers to iterate and improve design
solutions.
• Initiated virtual try-on and virtual store experience Increased the customer engagement NPS Score.
• Staying up-to-date with emerging trends and technologies in AR/VR virtual stores and translating in design.
• Collaborated with product managers, retailers, and Programming Skillss to meet business requirements.
• Mentored and trained a team of 3+ interns collaborated to increase the velocity and execution speed.
Crafter: Link May 2019 - June 2019 Front-End Intern Hyderabad, India
• As the sole developer on the project, assumed full responsibility for leading the engineering strategy and making technology decisions independently, ensuring efficient and effective project execution..
• Proactively seeking feedback and input from the executive team and reflecting in the in the product Frontend. AI PROJECTS

"""

# %%
summary = summariser(article, max_length =500, min_length=30, do_sample=True)
print(summary)
# Out:
# [{'summary_text': ' The candidate is currently pursuing a Master’s in Computer Science at the University of Colorado Boulder, Colorado . The candidate will be a Software Engineer with over 5 years of industrial experience . He has previously worked as an E-commerce, Consumer Technology, Finance and Networking Engineer .'}]

# %%
summary[0]['summary_text']
# Out:
# ' Despite widespread lack of familiarity, AI is a technology that is transforming every walk of life . We discuss novel applications in finance, national security, health care, criminal justice, transportation, and smart cities . We also address issues such as data access problems, algorithmic bias, AI ethics and transparency . We contrast the regulatory approaches of the U.S. and European Union .'
